# %%
import nltk; nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/'My Drive'/UniversalEmb
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: 'drive/My Drive/UniversalEmb'
# /content/drive/My Drive/UniversalEmb

# %%
#!git clone https://github.com/jasonwei20/eda_nlp
# Out:
# Cloning into 'eda_nlp'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 379 (delta 18), reused 1 (delta 0), pack-reused 349
# Receiving objects: 100% (379/379), 20.41 MiB | 13.57 MiB/s, done.
# Resolving deltas: 100% (181/181), done.

# %%
import pandas as pd
def read_trec50(file_name, typ=1):
  train = pd.read_csv(file_name, index_col=0)
  lbl2indx = {i:j for j, i in enumerate(train.labels.unique())}
  train.columns = ['text', 'labels']
  train['lbl_index'] = train.labels.apply(lambda x:lbl2indx[x])


  labels_t = [i.split(' ', 1)[0].split(':')[typ] for i in open('TREC_10.label', encoding = 'windows-1252').readlines()]
  texts_t = [ i.split(' ', 1)[1][:-1] for i in open('TREC_10.label', encoding = 'windows-1252').readlines()]
  test  = pd.DataFrame({'text':texts_t, 'labels': labels_t})
  test['lbl_index'] = test.labels.apply(lambda x:lbl2indx[x])

  return train, test, lbl2indx

train, test, l2i = read_trec50('trec50_splited/trec50_3k.csv')

# %%
import pandas as pd
def read_trec6(file_name, typ=0):
  train = pd.read_csv(file_name, index_col=0)
  lbl2indx = {i:j for j, i in enumerate(train.labels.unique())}
  train.columns = ['text', 'labels']
  train['lbl_index'] = train.labels.apply(lambda x:lbl2indx[x])


  labels_t = [i.split(' ', 1)[0].split(':')[typ] for i in open('TREC_10.label', encoding = 'windows-1252').readlines()]
  texts_t = [ i.split(' ', 1)[1][:-1] for i in open('TREC_10.label', encoding = 'windows-1252').readlines()]
  test  = pd.DataFrame({'text':texts_t, 'labels': labels_t})
  test['lbl_index'] = test.labels.apply(lambda x:lbl2indx[x])

  return train, test, lbl2indx
train, test, l2i = read_trec6('trec6_splited/trec6_splited_3k.csv')

# %%
train = pd.read_csv("sst2-splited/sst2_full_rev_5k.csv", index_col=0)
train.columns = ['text', 'labels']

# %%
# !mkdir sst2-splited/augmented_with_eda

# %%
f = open('sst2-splited/prepared_for_eda/sst2_full_rev_5k.csv', 'w')
for i, line in train.iterrows():
  f.write(str(line['labels'])+'\t'+ line['text']+'\n')

# %%
# !python eda_nlp/code/augment.py --input=sst2-splited/prepared_for_eda/sst2_full_rev_3k.csv --output=sst2-splited/augmented_with_eda/sst2_full_rev_3k.txt --num_aug=4 --alpha=0.1
# Out:
# generated augmented sentences with eda for sst2-splited/prepared_for_eda/sst2_full_rev_3k.csv to sst2-splited/augmented_with_eda/sst2_full_rev_3k.txt with num_aug=4
